# %%
import sys
sys.path.append('../scripts')
print (sys.version)

from run import *
from _heatmap import *
import matplotlib
import matplotlib.pyplot as plt
import warnings
import numpy as np
warnings.filterwarnings('ignore')
font = {'size': 10}
matplotlib.rc('font', **font)
# Out:
# 3.8.3 (default, Jul  2 2020, 16:21:59)
# [GCC 7.3.0]

# %%
plt.figure(figsize=(8,8))
plot_index = 1
ax = plt.subplot(1, 1, plot_index)

matrix, translated_rec_labels, ylabels, x_axis_label, y_axis_label = master('pdb_distance', '6VMS', 'D2_parameters.ini')
im,cbar = heatmap(matrix,translated_rec_labels,ylabels,ax=ax,cmap="Blues_r", cbarlabel="Distance")
texts = annotate_heatmap(im, valfmt="{x:.1f}", size=8)
ax.set_title('6VMS heavy atoms')
plt.ylabel(y_axis_label,**font)
plt.xlabel(x_axis_label,**font)
# Out:
# Text(0.5, 0, 'G protein residues')
